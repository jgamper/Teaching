# %% [markdown]
# Import necessary packages

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# Set plotting parameters. Keep the plots pretty!

# %%
sns.set_style("whitegrid") # darkgrid, white grid, dark, white and ticks
my_cmap = ListedColormap(sns.color_palette("pastel").as_hex())
plt.rc("axes", titlesize=18)     # fontsize of the axes title
plt.rc("axes", labelsize=14)    # fontsize of the x and y labels
plt.rc("xtick", labelsize=13)    # fontsize of the tick labels
plt.rc("ytick", labelsize=13)    # fontsize of the tick labels
plt.rc("legend", fontsize=13)    # legend fontsize
plt.rc("font", size=13)          # controls default text sizes

# %% [markdown]
# # Slide #9

# %%
N = 1000
x = np.random.randn(N)
x = 3
y = x + 1 + np.sqrt(3)*np.random.randn(N)
x = 3

# %%
sns.set(font_scale=2) 
df1 = pd.DataFrame.from_dict({"x": x, "y": y})
g = sns.JointGrid(data=df1,
                  x="x",
                  y="y",
                  height=8, 
                  ratio=5,
                  marginal_ticks=False)
g = g.plot_joint(sns.scatterplot, s=100, alpha=.9, c="blue")
g = g.plot_marginals(sns.histplot, kde=True)
r, p = stats.pearsonr(x=df1["x"], y=df1["y"])
# annotate the pearson correlation coefficient text to 2 decimal places
# g.ax_joint.text(3.5, 8.5, 'r = {:.2f}'.format(r))
fig = g.figure
fig.savefig("first.png", dpi=600)
# Out:
# /Users/jevgenijgamper/.pyenv/versions/3.8.9/envs/lectures-code/lib/python3.8/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
N = 1000
y = 1+2*np.random.randn(N)
x = 3
x = (y-1)/4 + np.sqrt(3)*np.random.randn(N)/2
x = 3

# %%
sns.set(font_scale=2) 
df2 = pd.DataFrame.from_dict({"x": x, "y": y})
g = sns.JointGrid(data=df2,
                  x="x",
                  y="y",
                  height=8, 
                  ratio=5,
                  marginal_ticks=False)
g = g.plot_joint(sns.scatterplot, s=100, alpha=.9, c="green")
g = g.plot_marginals(sns.histplot, kde=True)
r, p = stats.pearsonr(x=df2["x"], y=df2["y"])
# annotate the pearson correlation coefficient text to 2 decimal places
# g.ax_joint.text(4, 8.7, 'r = {:.2f}'.format(r))
fig = g.figure
fig.savefig("second.png", dpi=600)
# Out:
# /Users/jevgenijgamper/.pyenv/versions/3.8.9/envs/lectures-code/lib/python3.8/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
N = 1000
z = np.random.randn(N)
x = 3
x = z
x = 3
y = z + 1 + np.sqrt(3)*np.random.randn(N)

# %%
sns.set(font_scale=2) 
df3 = pd.DataFrame.from_dict({"x": x, "y": y})
g = sns.JointGrid(data=df3,
                  x="x",
                  y="y",
                  height=8, 
                  ratio=5,
                  marginal_ticks=False)
g = g.plot_joint(sns.scatterplot, s=100, alpha=.9, c="red")
g = g.plot_marginals(sns.histplot, kde=True)
# r, p = stats.pearsonr(x=df3["x"], y=df3["y"])
# annotate the pearson correlation coefficient text to 2 decimal places
# g.ax_joint.text(4, 3, 'r = {:.2f}'.format(r))
fig = g.figure
fig.savefig("third.png", dpi=600)

# %%
df1["target"] = "script 1"
df2["target"] = "script 2"
df3["target"] = "script 3"
df_all = pd.concat([df1, df2, df3], axis=0)
g=sns.displot(data=df_all, x="y", hue="target", stat="density", fill=True, color=["blue", "green", "red"], common_norm=False)
fig = g.figure
fig.savefig("marginal-do.png", dpi=600)
